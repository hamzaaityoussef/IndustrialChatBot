# %%
import os
os.chdir("../")

# %%
# %pwd
# %pip install langchain
# %pip install langchain-community
# Out:
# Requirement already satisfied: langchain in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (0.3.21)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain) (0.3.47)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain) (0.3.18)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-community
#   Using cached langchain_community-0.3.20-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-community) (0.3.47)
# Requirement already satisfied: langchain<1.0.0,>=0.3.21 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-community) (0.3.21)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.11.14-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-community) (9.0.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Using cached pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-community) (0.3.18)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numpy<3,>=1.26.2 (from langchain-community)
#   Downloading numpy-2.2.4-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.2.0-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.3.0-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.18.3-cp310-cp310-win_amd64.whl.metadata (71 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain<1.0.0,>=0.3.21->langchain-community) (0.3.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain<1.0.0,>=0.3.21->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain-community) (2.27.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus pc\.conda\envs\medimind\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Using cached langchain_community-0.3.20-py3-none-any.whl (2.5 MB)
# Downloading aiohttp-3.11.14-cp310-cp310-win_amd64.whl (442 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading numpy-2.2.4-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.9 MB 2.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/12.9 MB 2.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/12.9 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/12.9 MB 1.9 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.9 MB 1.8 MB/s eta 0:00:07
#    -------- ------------------------------- 2.6/12.9 MB 1.8 MB/s eta 0:00:06
#    -------- ------------------------------- 2.9/12.9 MB 1.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.4/12.9 MB 1.8 MB/s eta 0:00:06
#    ------------ --------------------------- 3.9/12.9 MB 1.9 MB/s eta 0:00:05
#    ------------- -------------------------- 4.5/12.9 MB 1.9 MB/s eta 0:00:05
#    --------------- ------------------------ 5.0/12.9 MB 1.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.2/12.9 MB 2.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.8/12.9 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 6.0/12.9 MB 1.9 MB/s eta 0:00:04
#    ------------------- -------------------- 6.3/12.9 MB 1.9 MB/s eta 0:00:04
#    -------------------- ------------------- 6.6/12.9 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 7.1/12.9 MB 1.8 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.3/12.9 MB 1.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.6/12.9 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 8.1/12.9 MB 1.8 MB/s eta 0:00:03
#    -------------------------- ------------- 8.7/12.9 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 8.9/12.9 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.4/12.9 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 10.0/12.9 MB 1.8 MB/s eta 0:00:02
#    ------------------------------- -------- 10.2/12.9 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 10.7/12.9 MB 1.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.9 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.5/12.9 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.9 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 1.9 MB/s eta 0:00:00
# Using cached pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl (51 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.2.0-cp310-cp310-win_amd64.whl (29 kB)
# Downloading propcache-0.3.0-cp310-cp310-win_amd64.whl (44 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.18.3-cp310-cp310-win_amd64.whl (90 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, propcache, numpy, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-community
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.14 aiosignal-1.3.2 attrs-25.3.0 dataclasses-json-0.6.7 frozenlist-1.5.0 httpx-sse-0.4.0 langchain-community-0.3.20 marshmallow-3.26.1 multidict-6.2.0 mypy-extensions-1.0.0 numpy-2.2.4 propcache-0.3.0 pydantic-settings-2.8.1 python-dotenv-1.0.1 typing-inspect-0.9.0 yarl-1.18.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
def load_pdf_file(data):
    loader= DirectoryLoader(data,
                            glob="*.pdf",
                            loader_cls=PyPDFLoader)

    documents=loader.load()

    return documents
